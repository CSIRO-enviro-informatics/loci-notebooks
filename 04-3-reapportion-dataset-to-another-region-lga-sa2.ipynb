# %%
# !pip install git+https://github.com/CSIRO-enviro-informatics/loci-scripts.git@master
# !pip install numpy pandas
# Out:
# Collecting git+https://github.com/CSIRO-enviro-informatics/loci-scripts.git@master
#   Cloning https://github.com/CSIRO-enviro-informatics/loci-scripts.git (to revision master) to /tmp/pip-req-build-supzq48c
#   Running command git clone -q https://github.com/CSIRO-enviro-informatics/loci-scripts.git /tmp/pip-req-build-supzq48c
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied: XlsxWriter in /opt/conda/lib/python3.7/site-packages (from pyloci==0.1.1.25) (1.2.9)
# Requirement already satisfied: SPARQLWrapper<=1.8.5 in /opt/conda/lib/python3.7/site-packages (from pyloci==0.1.1.25) (1.8.5)
# Collecting rdflib<=4.2.2
#   Downloading rdflib-4.2.2-py3-none-any.whl (344 kB)
#      |████████████████████████████████| 344 kB 15.6 MB/s eta 0:00:01
# Collecting python-dotenv<=0.11.0
#   Downloading python_dotenv-0.11.0-py2.py3-none-any.whl (17 kB)
# Collecting requests<=2.23.0
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 17.1 MB/s eta 0:00:01
# Requirement already satisfied: isodate in /opt/conda/lib/python3.7/site-packages (from rdflib<=4.2.2->pyloci==0.1.1.25) (0.6.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.7/site-packages (from rdflib<=4.2.2->pyloci==0.1.1.25) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<=2.23.0->pyloci==0.1.1.25) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<=2.23.0->pyloci==0.1.1.25) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<=2.23.0->pyloci==0.1.1.25) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<=2.23.0->pyloci==0.1.1.25) (3.0.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from isodate->rdflib<=4.2.2->pyloci==0.1.1.25) (1.15.0)
# Building wheels for collected packages: pyloci
#   Building wheel for pyloci (setup.py) ... done
#   Created wheel for pyloci: filename=pyloci-0.1.1.25-py3-none-any.whl size=34955 sha256=fb37c5e458c9292655154ac6afb5fbf8df5b5947bf25a440c91d9981bfd8d6ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jienk0o_/wheels/3e/5b/79/764b8572d0ff50a032783c6b4b6373567cf1ca9264f188d83d
# Successfully built pyloci
# Installing collected packages: rdflib, python-dotenv, requests, pyloci
#   Attempting uninstall: rdflib
#     Found existing installation: rdflib 5.0.0
#     Uninstalling rdflib-5.0.0:
#       Successfully uninstalled rdflib-5.0.0
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 0.13.0
#     Uninstalling python-dotenv-0.13.0:
#       Successfully uninstalled python-dotenv-0.13.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
#   Attempting uninstall: pyloci
#     Found existing installation: pyloci 0.1.2
#     Uninstalling pyloci-0.1.2:
#       Successfully uninstalled pyloci-0.1.2
# Successfully installed pyloci-0.1.1.25 python-dotenv-0.11.0 rdflib-4.2.2 requests-2.23.0
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (1.19.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %% [markdown]
# # Reapportioning ASGS16 LGA to SA2  example using the pyloci API
#
# This notebook show how you would perform reapportioning using the [pyloci](https://pypi.org/project/pyloci/) library using a simple CSV file. The pyloci library interfaces directly with the SPARQL API for the Loc-I Cache GraphDB.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('loci-lga-sa1-test-case1.csv', delimiter = ',')
#show the csv file read in
df
# Out:
#                                                  LGA  \
# 0  http://linked.data.gov.au/dataset/asgs2016/loc...
# 1  http://linked.data.gov.au/dataset/asgs2016/loc...
# 2  http://linked.data.gov.au/dataset/asgs2016/loc...
# 3  http://linked.data.gov.au/dataset/asgs2016/loc...
# 4  http://linked.data.gov.au/dataset/asgs2016/loc...
#
#    Estimated Agricultural Area  Estimated value 2016
# 0                       608800             118073000
# 1                    144111000                 39100
# 2                       254500             142090000
# 3                        18900               5195000
# 4                        74100              55850000

# %%
#sure the config for the SPARQL endpoint to hit is set
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
print(os.getenv("SPARQL_ENDPOINT"))
# Out:
# http://db.loci.cat/repositories/loci-cache

# %%
#import the reapportioning module from pyloci
from pyloci import reapportioning


from pyloci.api.util import Util as API_Util
from pyloci.sparql import util as sparql_util
import time

auth = None
api_util = API_Util()

# %%
toFeatureType = "http://linked.data.gov.au/def/asgs#StatisticalAreaLevel2"
LOCI_INTEGRATION_API = "https://api.loci.cat/api/v1"

# %%
# %%time
target_col = "Estimated value 2016"
res_df_cols = {
    "LGA" : [],
    "SA2" : [],
    "percent_overlap": [],
    target_col: [],
    "reapportioned_data": [],
}
for index, row in df.iterrows():
    fromFeature = row['LGA']
    print("{}, {}".format(row['LGA'], str(row[target_col])))
    print("Querying overlaps of {} to {}...".format(fromFeature, toFeatureType))
    tic = time.perf_counter()
    list_locations = api_util.query_api_location_overlaps(fromFeature, toFeatureType, LOCI_INTEGRATION_API, crosswalk='true')
    toc = time.perf_counter()
    print(f"query_api_location_overlaps took {toc - tic:0.4f} seconds")
    #print(list_locations)
    for o in list_locations['overlaps']:
        res_df_cols["LGA"].append(fromFeature)
        res_df_cols["SA2"].append(o['uri'])
        res_df_cols["percent_overlap"].append(o['forwardPercentage'])
        res_df_cols[target_col].append(row[target_col])
        reapportioned = (float(o['forwardPercentage'])/100.0)*float(row[target_col])
        res_df_cols["reapportioned_data"].append(reapportioned)
# Out:
# http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/55880, 118073000
# Querying overlaps of http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/55880 to http://linked.data.gov.au/def/asgs#StatisticalAreaLevel2...
# query_api_location_overlaps took 2.0697 seconds
# http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/40070, 39100
# Querying overlaps of http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/40070 to http://linked.data.gov.au/def/asgs#StatisticalAreaLevel2...
# query_api_location_overlaps took 8.7663 seconds
# http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080, 142090000
# Querying overlaps of http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080 to http://linked.data.gov.au/def/asgs#StatisticalAreaLevel2...
# query_api_location_overlaps took 10.9773 seconds
# http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050, 5195000
# Querying overlaps of http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050 to http://linked.data.gov.au/def/asgs#StatisticalAreaLevel2...
# query_api_location_overlaps took 13.2224 seconds
# http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/20110, 55850000
# Querying overlaps of http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/20110 to http://linked.data.gov.au/def/asgs#StatisticalAreaLevel2...
# query_api_location_overlaps took 5.7247 seconds
# CPU times: user 62.5 ms, sys: 5.02 ms, total: 67.5 ms
# Wall time: 40.8 s

# %%
res_df = pd.DataFrame (res_df_cols, columns = ['LGA', "SA2", "percent_overlap", target_col, "reapportioned_data"])
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_colwidth', 0)
res_df
# Out:
#                                                                      LGA  \
# 0   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/55880
# 1   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/40070
# 2   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/40070
# 3   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080
# 4   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080
# 5   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080
# 6   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080
# 7   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080
# 8   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/50080
# 9   http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050
# 10  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050
# 11  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050
# 12  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050
# 13  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/10050
# 14  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/20110
# 15  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/20110
# 16  http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/20110
#
#                                                                            SA2  \
# 0   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509021242
# 1   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/401011001
# 2   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/401011002
# 3   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509011225
# 4   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509011232
# 5   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509011227
# 6   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509011233
# 7   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509011226
# 8   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/509011229
# 9   http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/109011172
# 10  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/109011173
# 11  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/109011176
# 12  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/109011174
# 13  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/109011175
# 14  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/204031069
# 15  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/204031071
# 16  http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel2/204031075
#
#     percent_overlap  Estimated value 2016  reapportioned_data
# 0  100.00            118073000            118073001.58
# 1  67.31             39100                26318.24
# 2  32.69             39100                12782.36
# 3  0.71              142090000            1005309.74
# 4  3.31              142090000            4702543.39
# 5  0.58              142090000            819770.30
# 6  2.35              142090000            3335629.02
# 7  93.00             142090000            132141451.00
# 8  0.06              142090000            85364.94
# 9  33.18             5195000              1723723.89
# 10 7.90              5195000              410161.57
# 11 7.02              5195000              364521.49
# 12 15.83             5195000              822204.38
# 13 36.08             5195000              1874410.23
# 14 87.91             55850000             49095039.18
# 15 11.56             55850000             6454552.57
# 16 0.54              55850000             300434.70
