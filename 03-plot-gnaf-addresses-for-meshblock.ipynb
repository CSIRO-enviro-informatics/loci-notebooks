# %%
# !pip install ipyleaflet rdflib requests geodaisy pyproj shapely geopandas geomet tqdm
# Out:
# Requirement already satisfied: ipyleaflet in ./venv/lib/python3.6/site-packages (0.12.2)
# Requirement already satisfied: rdflib in ./venv/lib/python3.6/site-packages (4.2.2)
# Requirement already satisfied: requests in ./venv/lib/python3.6/site-packages (2.23.0)
# Requirement already satisfied: geodaisy in ./venv/lib/python3.6/site-packages (0.1.1)
# Requirement already satisfied: pyproj in ./venv/lib/python3.6/site-packages (2.5.0)
# Requirement already satisfied: shapely in ./venv/lib/python3.6/site-packages (1.7.0)
# Requirement already satisfied: geopandas in ./venv/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied: geomet in ./venv/lib/python3.6/site-packages (0.2.1.post1)
# Requirement already satisfied: tqdm in ./venv/lib/python3.6/site-packages (4.43.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xarray>=0.10 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (0.15.0)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (7.5.1)
# Requirement already satisfied: branca<0.4,>=0.3.1 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (0.3.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.6/site-packages (from rdflib) (2.4.6)
# Requirement already satisfied: isodate in ./venv/lib/python3.6/site-packages (from rdflib) (0.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./venv/lib/python3.6/site-packages (from requests) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./venv/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.6/site-packages (from requests) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in ./venv/lib/python3.6/site-packages (from requests) (2.9)
# Requirement already satisfied: typing in ./venv/lib/python3.6/site-packages (from geodaisy) (3.7.4.1)
# Requirement already satisfied: fiona in ./venv/lib/python3.6/site-packages (from geopandas) (1.8.13.post1)
# Requirement already satisfied: pandas>=0.23.0 in ./venv/lib/python3.6/site-packages (from geopandas) (1.0.1)
# Requirement already satisfied: click in ./venv/lib/python3.6/site-packages (from geomet) (7.0)
# Requirement already satisfied: six in ./venv/lib/python3.6/site-packages (from geomet) (1.14.0)
# Requirement already satisfied: traitlets>=4.2.2 in ./venv/lib/python3.6/site-packages (from traittypes<3,>=0.2.1->ipyleaflet) (4.3.3)
# Requirement already satisfied: numpy>=1.15 in ./venv/lib/python3.6/site-packages (from xarray>=0.10->ipyleaflet) (1.18.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.1.4)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (7.12.0)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.6/site-packages (from branca<0.4,>=0.3.1->ipyleaflet) (2.11.1)
# Requirement already satisfied: cligj>=0.5 in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: click-plugins>=1.0 in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=17 in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: munch in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: pytz>=2017.2 in ./venv/lib/python3.6/site-packages (from pandas>=0.23.0->geopandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in ./venv/lib/python3.6/site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: ipython-genutils in ./venv/lib/python3.6/site-packages (from traitlets>=4.2.2->traittypes<3,>=0.2.1->ipyleaflet) (0.2.0)
# Requirement already satisfied: decorator in ./venv/lib/python3.6/site-packages (from traitlets>=4.2.2->traittypes<3,>=0.2.1->ipyleaflet) (4.4.1)
# Requirement already satisfied: notebook>=4.4.1 in ./venv/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./venv/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.2.0)
# Requirement already satisfied: jupyter-core in ./venv/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (4.6.3)
# Requirement already satisfied: jupyter-client in ./venv/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.0)
# Requirement already satisfied: tornado>=4.2 in ./venv/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.3)
# Requirement already satisfied: setuptools>=18.5 in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (45.2.0)
# Requirement already satisfied: pickleshare in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: pygments in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (2.5.2)
# Requirement already satisfied: backcall in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./venv/lib/python3.6/site-packages (from jinja2->branca<0.4,>=0.3.1->ipyleaflet) (1.1.1)
# Requirement already satisfied: pyzmq>=17 in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (19.0.0)
# Requirement already satisfied: terminado>=0.8.1 in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: nbconvert in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (5.6.1)
# Requirement already satisfied: Send2Trash in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: prometheus-client in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in ./venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.1.8)
# Requirement already satisfied: parso>=0.5.2 in ./venv/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.1)
# Requirement already satisfied: testpath in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: bleach in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.3)
# Requirement already satisfied: defusedxml in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.4.2)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.0.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.5.1)

# %% [markdown]
# # Plot G-NAF addresses for a given ASGS MeshBlock
#
# This notebook demonstrates how you use Loc-I to identify GNAF Addresses from an input ASGS MeshBlock.
# This notebook shows you how to traverse across from one geographic dataset to another via `Loc-I Linksets`, specifically ASGS->GNAF.
# We show how to achieve this using the Loc-I Integration API (https://api.loci.cat).

# %%
import urllib, json, requests

# %%
# input meshblock
meshblock_uri ='http://linked.data.gov.au/dataset/asgs2016/meshblock/80000060000'
meshblock_uri = 'http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000'
meshblock_uri = 'http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000'
#tell me more about the meshblock
# get semantic info about the feature
header={'Accept': 'text/turtle'}
url = meshblock_uri
r = requests.get(url, headers=header)
res_body = r.text
print(res_body)
# Out:
# @prefix asgs: <http://linked.data.gov.au/def/asgs#> .
# @prefix asgs-cat: <http://linked.data.gov.au/def/asgs-cat/> .
# @prefix asgs-id: <http://linked.data.gov.au/def/asgs/id#> .
# @prefix data: <http://linked.data.gov.au/def/datatype/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix geo: <http://www.opengis.net/ont/geosparql#> .
# @prefix geox: <http://linked.data.gov.au/def/geox#> .
# @prefix loci: <http://linked.data.gov.au/def/loci#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://linked.data.gov.au/dataset/asgs2016/destinationzone/213202172> a asgs:DestinationZone ;
#     dcterms:identifier "213202172"^^asgs-id:dznCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/24970> a asgs:LocalGovernmentArea ;
#     dcterms:identifier "24970"^^asgs-id:lgaCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/naturalresourcemanagementregion/208> a asgs:NaturalResourceManagementRegion ;
#     dcterms:identifier "208"^^asgs-id:nrmrCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/stateorterritory/VIC> geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/statesuburb/20566> a asgs:StateSuburb ;
#     dcterms:identifier "20566"^^asgs-id:sscCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel1/21205132002> geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/meshblock/20426000000> a asgs:Feature,
#         asgs:MeshBlock,
#         geo:Feature ;
#     geox:hasAreaM2 [ data:value 1921709.450938964 ;
#             geox:inCRS <http://www.opengis.net/def/crs/EPSG/0/3857> ],
#         [ data:value 1194200.00000000023283064365386962890625 ;
#             geox:inCRS <http://www.opengis.net/def/crs/EPSG/0/3577> ] ;
#     loci:isMemberOf <http://linked.data.gov.au/dataset/asgs2016/meshblock/> ;
#     dcterms:identifier "20426000000"^^asgs-id:mbCode2016 ;
#     dcterms:type <http://linked.data.gov.au/def/asgs-cat/20> ;
#     geo:hasGeometry <http://gds.loci.cat/geometry/asgs16_mb/20426000000> ;
#     geo:sfWithin <http://linked.data.gov.au/dataset/asgs2016/destinationzone/213202172>,
#         <http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/24970>,
#         <http://linked.data.gov.au/dataset/asgs2016/naturalresourcemanagementregion/208>,
#         <http://linked.data.gov.au/dataset/asgs2016/stateorterritory/VIC>,
#         <http://linked.data.gov.au/dataset/asgs2016/statesuburb/20566>,
#         <http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel1/21205132002> .

# %%
#you could use rdflib to do some more digging into the semantic description to get the geometry... 
import rdflib
g=rdflib.Graph()
g.load(meshblock_uri)

#for s,p,o in g:
#    print(s, p, o)

geom_uri = None
for row in g.query(
            '''
            PREFIX geo: <http://www.opengis.net/ont/geosparql#>
            select ?g where { ?feature geo:hasGeometry ?g .}
            '''):
        geom_uri = (row.g)
if(geom_uri != None):
    print(geom_uri)
# Out:
# http://gds.loci.cat/geometry/asgs16_mb/20426000000

# %%
# get the geojson representation of the geom
header={'Accept': 'application/json'}
r = requests.get(geom_uri, headers=header)
geojson_data = r.json()

params={'_view': 'centroid'}
r = requests.get(geom_uri, headers=header, params=params)
centroid_geojson_data = r.json()

# %%
#draw the geometry for the feature on a map
import ipyleaflet as ipy 
import ipywidgets as ipyw
from ipyleaflet import GeoJSON, Map, Marker

x_coord = centroid_geojson_data['coordinates'][1]
y_coord = centroid_geojson_data['coordinates'][0]

map = ipy.Map(center=[x_coord, y_coord], zoom=15)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json1 = GeoJSON(data=geojson_data, style = {'color': 'red', 'opacity':1, 'weight':1.9, 'fillOpacity':0.5})
map.add_layer(geo_json1)
map
# Out:
# Map(center=[-37.910620529, 145.134765925], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in…

# %% [markdown]
# ## Find the related G-NAF addresses via the Loc-I Integration API
#
# We want to traverse the Loc-I linkset to get the G-NAF addresses

# %%
#we give the feature_type URI to the Loc-I API
feature_type = 'http://linked.data.gov.au/def/gnaf#Address'

payload = {
    'uri': meshblock_uri, 
    'areas': 'false',
    'proportion': 'false',
    'contains': 'false',
    'within':'true',
    'crosswalk':'true',
    'output_type' : feature_type,
    'count': 100,
    'offset': 0
}

url = "https://api.loci.cat/api/v1/location/overlaps"
r = requests.get(url, params=payload)
res = r.json()
res
# Out:
# {'meta': {'count': 156, 'offset': 0},
#  'overlaps': [{'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC413712007'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419752607'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419752608'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419778984'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420047980'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420047982'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420338218'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420645459'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420947680'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420964922'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421086193'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421272093'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421565077'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421676834'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423655480'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423993249'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424037723'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248941'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248943'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248947'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248949'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248951'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248966'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248978'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424248990'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424249002'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424249014'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424492444'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424548002'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424548003'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424548004'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424548005'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424548006'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424548007'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424590892'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424590893'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919558'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919559'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919560'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919561'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919562'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919563'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919564'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919565'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919566'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919567'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919568'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919569'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919570'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919571'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919572'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919573'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919574'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919575'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919576'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919577'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919578'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919579'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919580'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919581'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919582'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919583'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919584'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919585'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919586'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919587'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424919588'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731880'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731881'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731882'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731883'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731884'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731885'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731886'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731887'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731888'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731889'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731890'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731891'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731892'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731893'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731894'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731895'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731896'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731897'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731898'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731899'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731900'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731901'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731902'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731903'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425731904'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732195'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732196'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732197'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732198'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732199'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732200'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732201'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732202'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732203'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732204'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732205'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732206'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732207'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732208'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425732209'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425735695'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425735696'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425741136'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425742164'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425742165'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425742166'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425742167'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425742168'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425744559'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425744562'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760993'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760994'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760995'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760996'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760997'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760998'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425760999'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761000'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761001'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761002'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761003'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761004'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761005'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761006'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761007'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761008'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761009'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761010'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761376'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761377'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761378'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761379'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761380'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761381'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761382'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761383'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761592'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761593'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761594'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425761595'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425763037'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425764247'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425764348'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425764349'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425772580'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425777109'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425788239'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425788240'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425788241'}]}

# %% [markdown]
# Let's go ahead and process each address to get the spatial object and add them to the map

# %%
#load the resources into a graph object
address_graph = rdflib.Graph()
from tqdm import tqdm

for r in tqdm(res['overlaps']):
    address_graph.load(r['uri'])

#for s,p,o in address_graph:
#    print(s, p, o)
# Out:
# 100%|██████████| 156/156 [01:01<00:00,  2.55it/s]

# %%
list_of_geom_obj = []
for row in address_graph.query(
            '''
            PREFIX geo: <http://www.opengis.net/ont/geosparql#>
            select distinct ?wkt ?type ?label ?note
            where { 
                   # ?f rdfs:comment ?note .
                   # ?f geo:hasGeometry ?g .
                   # ?g geo:asWKT ?wkt .
                   # ?g dct:type ?type .
                   # ?g rdfs:label ?label .
               }
            ORDER BY ?note
            '''):
        geom = (str(row.wkt), str(row.type), row.label.value, row.note.value)
        list_of_geom_obj.append(geom)
        print(geom)
# Out:
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13518899 -37.90589628)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', '100 Normanby Road, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '13 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13885566 -37.91597185)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', '136 Wellington Road, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '15 Innovation Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '20 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '20 Research Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '21 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.12823978 -37.90614018)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '36 Gardiner Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '42 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '42 Scenic Boulevard, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '44 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', '52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '55 Scenic Boulevard, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '58 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', '8 Scenic Boulevard, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Atm 29 21 Chancellors Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Atm 9 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Atm 9 21 Chancellors Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Bldg 42 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Deakin Hall 56 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Farrer Hall 62 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Howitt Hall 60 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Monash Uni 21 Sports Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Monash Uni 27 Sports Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Monash Uni 28 Sports Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Monash Uni 38 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Monash University 1-131 Wellington Road, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13677589 -37.90607684)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Nottinghill Childrens Service 201-211 Normanby Road, Notting Hill, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Richardson Hall 63 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Roberts Hall 61 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Se 2 15 Innovation Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Se 3 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Se 4 42 Scenic Boulevard, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Se 8 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 1 13 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 1 15 Innovation Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 1 20 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 1 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 1 New Horizons Building 20 Research Way, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 10 Monash University 1-131 Wellington Road, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 11 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 12 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 13 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 13 21 Chancellors Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 15 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 15 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 16 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 17 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 17 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 19 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 2 13 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 2 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 2 42 Scenic Boulevard, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 20 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 22 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 23 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 24 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 25 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 26 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 27 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 28 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 3 13 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 30 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 33 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 34 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13464385 -37.91524603)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 38 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 4 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 4 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 5 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 5 42 Scenic Boulevard, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 6 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 6 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Shop 7 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Twr 16 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Twr 16 21 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 1 13 College Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 1 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 1 58 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 10 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 10 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 10B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 10B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 11 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 11 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 11B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 11B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 12 21 Chancellors Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 12 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 12B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 12B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 13 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 13B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 13B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 14 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 14B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 14B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 15 21 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 15 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 158 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 15B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 16 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 16B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 17 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 17B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 1B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 1B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 2 13 College Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 2 21 Chancellors Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 2 42 Scenic Boulevard, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 2 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 2 58 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 20 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 22 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 23 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 24 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 25 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 26 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 27 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 28 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 29 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 2B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 2B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 3 13 College Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 3 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 3 58 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 30 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 32 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 34 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 35 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 3B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 3B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 4 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 4 58 College Walk, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 4B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 4B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 5 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 5B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 5B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 6 21 Chancellors Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 6 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 6B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 6B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 7 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 7 21 Chancellors Walk, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 7 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 7B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 7B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 8 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 8B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 8B2 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13297773 -37.91397153)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality', 'Unit 9 52 Ancora Imparo Way, Clayton, VIC 3168')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 9B1 1-131 Wellington Road, Clayton, VIC 3800')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(145.13390076 -37.91515521)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback', 'Unit 9B2 1-131 Wellington Road, Clayton, VIC 3800')

# %%
#setup a new leaflet map with the meshblock
map2 = ipy.Map(center=[x_coord, y_coord], zoom=14)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))
map2.add_layer(geo_json1)

import re
from pyproj import Transformer
from shapely.wkt import dumps, loads
from geomet import wkt
from shapely.ops import transform

#add layer for each wkt
for geom_obj in list_of_geom_obj:
    #print(geom_obj[0])
    m = re.search('<(.*)> (.*)', geom_obj[0])
    crs = m.group(1)
    wktdata = m.group(2)
    #transform crs to epsg 4326 if needed...
    if crs == 'http://www.opengis.net/def/crs/EPSG/0/4283':
        project = Transformer.from_crs("EPSG:4283", "EPSG:4326")            
        wktdata = loads(wktdata)
        g2 = transform(project.transform, wktdata)  # apply projection   
        wktdata = dumps(g2)
        #print(wktdata)
    geojson_data = wkt.loads(wktdata)
    #print(geojson_data)
            
    geojson = GeoJSON(data=geojson_data, style = {'color': 'blue', 'fillcolor': 'blue', 'opacity':1, 'weight':1.9, 'fillOpacity':0.1})
    map2.add_layer(geojson)
map2
# Out:
# Map(center=[-37.910620529, 145.134765925], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in…

# %% [markdown]
# Ta-da!
#
# You can see GNAF addresses as blue markers within the meshblock (shown in red).
#
# We hope you enjoyed that little demonstration of how to traverse from a ASGS MeshBlock across to the GNAF Address based on linkset relationships registered in Loc-I.
