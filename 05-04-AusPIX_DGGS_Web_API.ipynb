# %% [markdown]
# # DGGS Web API functionality via AusPIX DGGS API
#
# This notebook shows usage of prototype DGGS functionality via the AusPIX_DGGS_API (web api implemented using Flask). See https://github.com/CSIRO-enviro-informatics/AusPIX_DGGS_API
#
# This is currently hosted as a demo at https://dggs.loci.cat/

# %%
import json
import requests

geojson_data = {
        "type": "FeatureCollection",
        "features": [
          {
            "type": "Feature",
            "properties": {},
            "geometry": {
              "type": "Polygon",
              "coordinates": [
                [
                  [
                    149.02233123779297,
                    -35.294111494793285
                  ],
                  [
                    149.14112091064453,
                    -35.294111494793285
                  ],
                  [
                    149.14112091064453,
                    -35.21252670530204
                  ],
                  [
                    149.02233123779297,
                    -35.21252670530204
                  ],
                  [
                    149.02233123779297,
                    -35.294111494793285
                  ]
                ]
              ]
            }
          }
        ]
}

# %%
#draw the geometry for the feature on a map
import ipyleaflet as ipy 
import ipywidgets as ipyw
from ipyleaflet import GeoJSON, Map, Marker

x_coord = -35.282
y_coord = 149.09

map1 = ipy.Map(center=[x_coord, y_coord], zoom=9)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json1 = GeoJSON(data=geojson_data, style = {'color': 'red', 'opacity':0.8, 'weight':1.9, 'fillOpacity':0.3})
map1.add_layer(geo_json1)
map1
# Out:
# Map(center=[-35.282, 149.09], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
dggs_api_param = {
    'resolution' : 8,
    "dggs_as_polygon" : False
}

# %%
r = requests.post("https://dggs.loci.cat/api/search/find_dggs_by_geojson", params=dggs_api_param, json=geojson_data)
print(r.status_code)
res = r.json()
# Out:
# 200

# %%
res
# Out:
# {'meta': {'cells_count': 40},
#  'dggs_cells': ['R78523431',
#   'R78523432',
#   'R78523440',
#   'R78523441',
#   'R78523442',
#   'R78523450',
#   'R78523451',
#   'R78523452',
#   'R78523434',
#   'R78523435',
#   'R78523443',
#   'R78523444',
#   'R78523445',
#   'R78523453',
#   'R78523454',
#   'R78523455',
#   'R78523437',
#   'R78523438',
#   'R78523446',
#   'R78523447',
#   'R78523448',
#   'R78523456',
#   'R78523457',
#   'R78523458',
#   'R78523461',
#   'R78523462',
#   'R78523470',
#   'R78523471',
#   'R78523472',
#   'R78523480',
#   'R78523481',
#   'R78523482',
#   'R78523464',
#   'R78523465',
#   'R78523473',
#   'R78523474',
#   'R78523475',
#   'R78523483',
#   'R78523484',
#   'R78523485']}

# %%
dggs_api_param = {
    'resolution' : 8,
    "dggs_as_polygon" : True
}

# %%
r = requests.post("https://dggs.loci.cat/api/search/find_dggs_by_geojson", params=dggs_api_param, json=geojson_data)
print(r.status_code)
res = r.json()
res
# Out:
# 200
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.026063, -35.217778],
#       [149.039781, -35.217778],
#       [149.039781, -35.232031],
#       [149.026063, -35.232031],
#       [149.026063, -35.217778]]]},
#    'properties': {'dggs_cell_id': 'R78523431'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.039781, -35.217778],
#       [149.053498, -35.217778],
#       [149.053498, -35.232031],
#       [149.039781, -35.232031],
#       [149.039781, -35.217778]]]},
#    'properties': {'dggs_cell_id': 'R78523432'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.053498, -35.217778],
#       [149.067215, -35.217778],
#       [149.067215, -35.232031],
#       [149.053498, -35.232031],
#       [149.053498, -35.217778]]]},
#    'properties': {'dggs_cell_id': 'R78523440'}},
#   {'type': 'Feature',
# ...

# %%
#draw the geometry for the feature on a map
x_coord = -35.282
y_coord = 149.09


map2 = ipy.Map(center=[x_coord, y_coord], zoom=9)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json2 = GeoJSON(data=res, style = {'color': 'blue', 'opacity':0.8, 'weight':1.9, 'fillOpacity':0.3})
map2.add_layer(geo_json2)
map2
# Out:
# Map(center=[-35.282, 149.09], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
## Load a more complicated geojson example

import geojson
fname = "./ACT_SA1_Black_Mountain.geojson"
geojson_data3 = None
with open(fname) as json_file:
    geojson_data3 = geojson.load(json_file)
    print(geojson_data3)
# Out:
# {"crs": {"properties": {"name": "urn:ogc:def:crs:OGC:1.3:CRS84"}, "type": "name"}, "features": [{"geometry": {"coordinates": [[[[149.087858, -35.284826], [149.087872, -35.284597], [149.08651, -35.284354], [149.086064, -35.284264], [149.085762, -35.284182], [149.08563, -35.28414], [149.085431, -35.284054], [149.085454, -35.284017], [149.085645, -35.283678], [149.08578, -35.283409], [149.085937, -35.283058], [149.086059, -35.282742], [149.086179, -35.282381], [149.086278, -35.282016], [149.086371, -35.281566], [149.086403, -35.28136], [149.086465, -35.28063], [149.086495, -35.280245], [149.08656, -35.279497], [149.086637, -35.278966], [149.086739, -35.278437], [149.086839, -35.278016], [149.087071, -35.276917], [149.087132, -35.276662], [149.087196, -35.276408], [149.087261, -35.276155], [149.087494, -35.275312], [149.088071, -35.273695], [149.088252, -35.272825], [149.08831, -35.271925], [149.088214, -35.270874], [149.087957, -35.269879], [149.087668, -35.26917], [149.086578, -35.2669
# ...

# %%
x_coord = -35.282
y_coord = 149.09

map3 = ipy.Map(center=[x_coord, y_coord], zoom=13)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json3 = GeoJSON(data=geojson_data3, style = {'color': 'purple', 'opacity':0.8, 'weight':1.9, 'fillOpacity':0.3})
map3.add_layer(geo_json3)
map3
# Out:
# Map(center=[-35.282, 149.09], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
dggs_api_param = {
    'resolution' : 8,
    "dggs_as_polygon" : True
}
r = requests.post("https://dggs.loci.cat/api/search/find_dggs_by_geojson", params=dggs_api_param, json=geojson_data3)
print(r.status_code)
res = r.json()
# Out:
# 200

# %%
#draw the geometry for the feature on a map
x_coord = -35.282
y_coord = 149.09


map4 = ipy.Map(center=[x_coord, y_coord], zoom=13)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json4 = GeoJSON(data=res, style = {'color': 'blue', 'opacity':0.8, 'weight':1.9, 'fillOpacity':0.3})
map4.add_layer(geo_json4)
map4
# Out:
# Map(center=[-35.282, 149.09], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
dggs_api_param = {
    'resolution' : 10,
    "dggs_as_polygon" : True
}
r = requests.post("https://dggs.loci.cat/api/search/find_dggs_by_geojson", params=dggs_api_param, json=geojson_data3)
print(r.status_code)
res = r.json()

#draw the geometry for the feature on a map
x_coord = -35.282
y_coord = 149.09

map4 = ipy.Map(center=[x_coord, y_coord], zoom=13)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json4 = GeoJSON(data=res, style = {'color': 'blue', 'opacity':0.8, 'weight':1.9, 'fillOpacity':0.3})
#add the original data
map4.add_layer(geo_json3)
map4.add_layer(geo_json4)

map4
# Out:
# 200
# Map(center=[-35.282, 149.09], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
#iterate over features in feature collection and query Loc-I API for features
def find_features_at_dggs_cell(dggs_cell_id):
    payload = {
        'dggs_cell' : dggs_cell_id
    }
    r = requests.get('https://api.loci.cat/api/v1/location/find-at-DGGS-cell', params=payload)
    json_res = r.json()
    return json_res

# %%
res
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.088554, -35.257377],
#       [149.090078, -35.257377],
#       [149.090078, -35.258962],
#       [149.088554, -35.258962],
#       [149.088554, -35.257377]]]},
#    'properties': {'dggs_cell_id': 'R7852344875',
#     'style': {'color': 'blue',
#      'opacity': 0.8,
#      'weight': 1.9,
#      'fillOpacity': 0.3}}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.090078, -35.257377],
#       [149.091602, -35.257377],
#       [149.091602, -35.258962],
#       [149.090078, -35.258962],
#       [149.090078, -35.257377]]]},
#    'properties': {'dggs_cell_id': 'R7852344883',
#     'style': {'color': 'blue',
#      'opacity': 0.8,
#      'weight': 1.9,
#      'fillOpacity': 0.3}}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.087029, -35.258962],
# ...

# %%
target_feature_type = 'asgs16_lga'
set_of_lga_features = set([])

#print(feature_collection)
for feature in res['features']:
    cell_id = feature['properties']['dggs_cell_id']
    print("Processing {}".format(cell_id))
    res = find_features_at_dggs_cell(cell_id)
    if 'locations' in res:
        for loc in res['locations']:
            if 'dataType' in loc and loc['dataType'] == target_feature_type:
                set_of_lga_features.add(loc['uri'])
                print("Adding {}".format(loc['uri']))
# Out:
# Processing R7852344875
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852344883
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852344877
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852344878
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852344886
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852344887
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852344888
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852347211
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852347212
# Adding http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/89399
# Processing R7852347220
# ...

# %%
map5 = ipy.Map(center=[x_coord, y_coord], zoom=10)

# %%
def get_geom(loci_uri):
    payload = {
        "uri": loci_uri
    }
    url = "https://api.loci.cat/api/v1/location/geometry"
    r = requests.get(url, params=payload)
    res = r.json()
    #get the first geom result
    geojson_data = []
    if len( res['geometry']) > 0:
        geojson_data = res['geometry'][0]
    return geojson_data

for feature_uri in list(set_of_lga_features):
    geojson_data = get_geom(feature_uri)
    curr_geojson_layer = GeoJSON(data=geojson_data, 
                    style={
                          'color': 'black', 
                          'opacity': 1, 
                          'weight':1, 
                          'fillColor': 'yellow', 
                          'fillOpacity': 0.3})
    map5.add_layer(curr_geojson_layer)
map5.add_layer(geo_json1)
map5.add_layer(geo_json2)

# %%
map5
# Out:
# Map(center=[-35.282, 149.09], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…
