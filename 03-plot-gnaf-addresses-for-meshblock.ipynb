# %%
# !pip install ipyleaflet rdflib requests geodaisy pyproj shapely geopandas geomet tqdm
# Out:
# Requirement already satisfied: ipyleaflet in ./venv/lib/python3.6/site-packages (0.12.2)
# Requirement already satisfied: rdflib in ./venv/lib/python3.6/site-packages (4.2.2)
# Requirement already satisfied: requests in ./venv/lib/python3.6/site-packages (2.23.0)
# Requirement already satisfied: geodaisy in ./venv/lib/python3.6/site-packages (0.1.1)
# Requirement already satisfied: pyproj in ./venv/lib/python3.6/site-packages (2.5.0)
# Requirement already satisfied: shapely in ./venv/lib/python3.6/site-packages (1.7.0)
# Requirement already satisfied: geopandas in ./venv/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied: geomet in ./venv/lib/python3.6/site-packages (0.2.1.post1)
# Requirement already satisfied: tqdm in ./venv/lib/python3.6/site-packages (4.43.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xarray>=0.10 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (0.15.0)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (7.5.1)
# Requirement already satisfied: branca<0.4,>=0.3.1 in ./venv/lib/python3.6/site-packages (from ipyleaflet) (0.3.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.6/site-packages (from rdflib) (2.4.6)
# Requirement already satisfied: isodate in ./venv/lib/python3.6/site-packages (from rdflib) (0.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./venv/lib/python3.6/site-packages (from requests) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./venv/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.6/site-packages (from requests) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in ./venv/lib/python3.6/site-packages (from requests) (2.9)
# Requirement already satisfied: typing in ./venv/lib/python3.6/site-packages (from geodaisy) (3.7.4.1)
# Requirement already satisfied: fiona in ./venv/lib/python3.6/site-packages (from geopandas) (1.8.13.post1)
# Requirement already satisfied: pandas>=0.23.0 in ./venv/lib/python3.6/site-packages (from geopandas) (1.0.1)
# Requirement already satisfied: click in ./venv/lib/python3.6/site-packages (from geomet) (7.0)
# Requirement already satisfied: six in ./venv/lib/python3.6/site-packages (from geomet) (1.14.0)
# Requirement already satisfied: traitlets>=4.2.2 in ./venv/lib/python3.6/site-packages (from traittypes<3,>=0.2.1->ipyleaflet) (4.3.3)
# Requirement already satisfied: numpy>=1.15 in ./venv/lib/python3.6/site-packages (from xarray>=0.10->ipyleaflet) (1.18.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.1.4)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in ./venv/lib/python3.6/site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (7.12.0)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.6/site-packages (from branca<0.4,>=0.3.1->ipyleaflet) (2.11.1)
# Requirement already satisfied: cligj>=0.5 in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: click-plugins>=1.0 in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=17 in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: munch in ./venv/lib/python3.6/site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: pytz>=2017.2 in ./venv/lib/python3.6/site-packages (from pandas>=0.23.0->geopandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in ./venv/lib/python3.6/site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: ipython-genutils in ./venv/lib/python3.6/site-packages (from traitlets>=4.2.2->traittypes<3,>=0.2.1->ipyleaflet) (0.2.0)
# Requirement already satisfied: decorator in ./venv/lib/python3.6/site-packages (from traitlets>=4.2.2->traittypes<3,>=0.2.1->ipyleaflet) (4.4.1)
# Requirement already satisfied: notebook>=4.4.1 in ./venv/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./venv/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.2.0)
# Requirement already satisfied: jupyter-core in ./venv/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (4.6.3)
# Requirement already satisfied: jupyter-client in ./venv/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.0)
# Requirement already satisfied: tornado>=4.2 in ./venv/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.3)
# Requirement already satisfied: setuptools>=18.5 in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (45.2.0)
# Requirement already satisfied: pickleshare in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: pygments in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (2.5.2)
# Requirement already satisfied: backcall in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in ./venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./venv/lib/python3.6/site-packages (from jinja2->branca<0.4,>=0.3.1->ipyleaflet) (1.1.1)
# Requirement already satisfied: pyzmq>=17 in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (19.0.0)
# Requirement already satisfied: terminado>=0.8.1 in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: nbconvert in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (5.6.1)
# Requirement already satisfied: Send2Trash in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: prometheus-client in ./venv/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in ./venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.1.8)
# Requirement already satisfied: parso>=0.5.2 in ./venv/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.1)
# Requirement already satisfied: testpath in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: bleach in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.3)
# Requirement already satisfied: defusedxml in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./venv/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.4.2)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.0.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.5.1)

# %% [markdown]
# # Plot G-NAF addresses for a given ASGS MeshBlock
#
# This notebook demonstrates how you use Loc-I to identify GNAF Addresses from an input ASGS MeshBlock.
# This notebook shows you how to traverse across from one geographic dataset to another via `Loc-I Linksets`, specifically ASGS->GNAF.
# We show how to achieve this using the Loc-I Integration API (https://api.loci.cat).

# %%
import urllib, json, requests

# %%
# input meshblock
meshblock_uri ='http://linked.data.gov.au/dataset/asgs2016/meshblock/80000060000'
meshblock_uri = 'http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000'
#tell me more about the meshblock
# get semantic info about the feature
header={'Accept': 'text/turtle'}
url = meshblock_uri
r = requests.get(url, headers=header)
res_body = r.text
print(res_body)
# Out:
# @prefix asgs: <http://linked.data.gov.au/def/asgs#> .
# @prefix asgs-cat: <http://linked.data.gov.au/def/asgs-cat/> .
# @prefix asgs-id: <http://linked.data.gov.au/def/asgs/id#> .
# @prefix data: <http://linked.data.gov.au/def/datatype/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix geo: <http://www.opengis.net/ont/geosparql#> .
# @prefix geox: <http://linked.data.gov.au/def/geox#> .
# @prefix loci: <http://linked.data.gov.au/def/loci#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://linked.data.gov.au/dataset/asgs2016/destinationzone/211160001> a asgs:DestinationZone ;
#     dcterms:identifier "211160001"^^asgs-id:dznCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/25060> a asgs:LocalGovernmentArea ;
#     dcterms:identifier "25060"^^asgs-id:lgaCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/naturalresourcemanagementregion/208> a asgs:NaturalResourceManagementRegion ;
#     dcterms:identifier "208"^^asgs-id:nrmrCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/stateorterritory/VIC> geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/statesuburb/21730> a asgs:StateSuburb ;
#     dcterms:identifier "21730"^^asgs-id:sscCode2016 ;
#     geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel1/20603111625> geo:sfContains <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> .
#
# <http://linked.data.gov.au/dataset/asgs2016/meshblock/20444240000> a asgs:Feature,
#         asgs:MeshBlock,
#         geo:Feature ;
#     geox:hasAreaM2 [ data:value 72228.561338728658 ;
#             geox:inCRS <http://www.opengis.net/def/crs/EPSG/0/3857> ],
#         [ data:value 45100.0 ;
#             geox:inCRS <http://www.opengis.net/def/crs/EPSG/0/3577> ] ;
#     loci:isMemberOf <http://linked.data.gov.au/dataset/asgs2016/meshblock/> ;
#     dcterms:identifier "20444240000"^^asgs-id:mbCode2016 ;
#     dcterms:type <http://linked.data.gov.au/def/asgs-cat/15> ;
#     geo:hasGeometry <http://gds.loci.cat/geometry/asgs16_mb/20444240000> ;
#     geo:sfWithin <http://linked.data.gov.au/dataset/asgs2016/destinationzone/211160001>,
#         <http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/25060>,
#         <http://linked.data.gov.au/dataset/asgs2016/naturalresourcemanagementregion/208>,
#         <http://linked.data.gov.au/dataset/asgs2016/stateorterritory/VIC>,
#         <http://linked.data.gov.au/dataset/asgs2016/statesuburb/21730>,
#         <http://linked.data.gov.au/dataset/asgs2016/statisticalarealevel1/20603111625> .

# %%
#you could use rdflib to do some more digging into the semantic description to get the geometry... 
import rdflib
g=rdflib.Graph()
g.load(meshblock_uri)

#for s,p,o in g:
#    print(s, p, o)

geom_uri = None
for row in g.query(
            '''
            PREFIX geo: <http://www.opengis.net/ont/geosparql#>
            select ?g where { ?feature geo:hasGeometry ?g .}
            '''):
        geom_uri = (row.g)
if(geom_uri != None):
    print(geom_uri)
# Out:
# http://gds.loci.cat/geometry/asgs16_mb/20444240000

# %%
# get the geojson representation of the geom
header={'Accept': 'application/json'}
r = requests.get(geom_uri, headers=header)
geojson_data = r.json()

params={'_view': 'centroid'}
r = requests.get(geom_uri, headers=header, params=params)
centroid_geojson_data = r.json()

# %%
#draw the geometry for the feature on a map
import ipyleaflet as ipy 
import ipywidgets as ipyw
from ipyleaflet import GeoJSON, Map, Marker

x_coord = centroid_geojson_data['coordinates'][1]
y_coord = centroid_geojson_data['coordinates'][0]

map = ipy.Map(center=[x_coord, y_coord], zoom=15)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

geo_json1 = GeoJSON(data=geojson_data, style = {'color': 'red', 'opacity':1, 'weight':1.9, 'fillOpacity':0.5})
map.add_layer(geo_json1)
map
# Out:
# Map(center=[-37.765549186, 144.92168454], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_…

# %% [markdown]
# ## Find the related G-NAF addresses via the Loc-I Integration API
#
# We want to traverse the Loc-I linkset to get the G-NAF addresses

# %%
#we give the feature_type URI to the Loc-I API
feature_type = 'http://linked.data.gov.au/def/gnaf#Address'

payload = {
    'uri': meshblock_uri, 
    'areas': 'false',
    'proportion': 'false',
    'contains': 'false',
    'within':'true',
    'crosswalk':'true',
    'output_type' : feature_type,
    'count': 100,
    'offset': 0
}

url = "https://api.loci.cat/api/v1/location/overlaps"
r = requests.get(url, params=payload)
res = r.json()
res
# Out:
# {'meta': {'count': 195, 'offset': 0},
#  'overlaps': [{'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412936137'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412938189'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412938190'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412938191'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412938192'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412938193'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412938194'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412948797'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412951792'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412952518'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412952525'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412952526'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412952690'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412953305'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412953306'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC412956370'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419579869'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419761824'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419839321'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC419888885'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420035170'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420172935'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420184679'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420210022'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420214926'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420217073'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420315226'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420351614'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420351615'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420434096'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420487893'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420520035'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420520234'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420520235'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420647951'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420729280'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420750497'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420793240'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420819247'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420824821'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420824825'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420943049'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC420978914'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421047508'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421106965'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421233613'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421238766'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421348934'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421367826'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421397630'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421617322'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421675546'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421682993'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421713290'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421730710'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421757229'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421757230'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421864252'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421871789'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421884309'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC421884310'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC422156872'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC422290254'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630748'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630749'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630750'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630751'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630752'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630753'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630754'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630755'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630756'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630757'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630758'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423630759'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423660768'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804912'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804913'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804914'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804915'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804916'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804917'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804918'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804919'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804920'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804921'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804922'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804923'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804924'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804925'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804926'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804927'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804928'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC423804929'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424465784'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424465785'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467503'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467504'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467505'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467506'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467507'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467508'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467509'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467510'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467511'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467512'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467513'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467514'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467515'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467516'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467517'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467518'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467519'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467520'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467521'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467522'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467523'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467524'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467525'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467526'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467527'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467528'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467529'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467530'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467531'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467532'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467533'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467534'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467535'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467536'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467537'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467538'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467539'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467540'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467541'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467542'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467543'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467544'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424467545'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424468125'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424468126'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424468130'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424468131'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424473199'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424473213'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424483092'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424493679'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424493682'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424493683'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424896811'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424896812'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC424898482'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425015796'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425015797'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425017960'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425017961'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425017962'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425017963'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425017964'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425339596'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425339597'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425517933'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630884'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630885'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630886'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630887'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630888'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630889'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630890'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630891'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630892'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630893'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630894'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630895'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630896'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630897'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630898'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630899'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630900'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630901'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630902'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425630903'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677488'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677489'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677490'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677491'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677492'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677493'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677494'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677495'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677496'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677497'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677498'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677499'},
#   {'uri': 'http://linked.data.gov.au/dataset/gnaf-2016-05/address/GAVIC425677500'}]}

# %% [markdown]
# Let's go ahead and process each address to get the spatial object and add them to the map

# %%
#load the resources into a graph object
address_graph = rdflib.Graph()
from tqdm import tqdm

for r in tqdm(res['overlaps']):
    address_graph.load(r['uri'])

#for s,p,o in address_graph:
#    print(s, p, o)
# Out:
# 100%|██████████| 195/195 [01:17<00:00,  2.51it/s]

# %%
list_of_geom_obj = []
for row in address_graph.query(
            '''
            PREFIX geo: <http://www.opengis.net/ont/geosparql#>
            select distinct ?wkt ?type ?label
            where { 
                   # ?f geo:hasGeometry ?g .
                   # ?g geo:asWKT ?wkt .
                   # ?g dct:type ?type .
                   # ?g rdfs:label ?label .
               }
            '''):
        geom = (str(row.wkt), str(row.type), row.label.value)
        list_of_geom_obj.append(geom)
        print(geom)
# Out:
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92295373 -37.76602881)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92169718 -37.76577040)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92046318 -37.76506641)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.91970530 -37.76560266)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92001095 -37.76502191)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92233100 -37.76546000)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92190408 -37.76585280)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92186900 -37.76590500)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92142882 -37.76562470)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#Locality', 'Locality')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92293047 -37.76537433)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#Gap', 'Gap ')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92364414 -37.76556795)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92034729 -37.76544575)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92221764 -37.76594739)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.91964683 -37.76506206)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92232400 -37.76550500)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92234500 -37.76537400)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92237100 -37.76520900)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92023735 -37.76572318)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92362900 -37.76579200)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92403016 -37.76618413)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92050400 -37.76507000)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92163415 -37.76587855)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92226713 -37.76569378)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92395310 -37.76603865)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92042186 -37.76506218)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92301485 -37.76532630)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92043400 -37.76515700)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92236500 -37.76525200)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92233800 -37.76541600)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92229753 -37.76559035)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92097486 -37.76582081)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92181559 -37.76567951)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#StreetLocality', 'Street Locality')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92235100 -37.76533600)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92235800 -37.76529400)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')
# ('<http://www.opengis.net/def/crs/EPSG/0/4283> POINT(144.92231000 -37.76554800)', 'http://gnafld.net/def/gnaf/code/GeocodeTypes#FrontageCentreSetback', 'Frontage Centre Setback')

# %%
#setup a new leaflet map with the meshblock
map2 = ipy.Map(center=[x_coord, y_coord], zoom=14)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))
map2.add_layer(geo_json1)

import re
from pyproj import Transformer
from shapely.wkt import dumps, loads
from geomet import wkt
from shapely.ops import transform

#add layer for each wkt
for geom_obj in list_of_geom_obj:
    #print(geom_obj[0])
    m = re.search('<(.*)> (.*)', geom_obj[0])
    crs = m.group(1)
    wktdata = m.group(2)
    #transform crs to epsg 4326 if needed...
    if crs == 'http://www.opengis.net/def/crs/EPSG/0/4283':
        project = Transformer.from_crs("EPSG:4283", "EPSG:4326")            
        wktdata = loads(wktdata)
        g2 = transform(project.transform, wktdata)  # apply projection   
        wktdata = dumps(g2)
        #print(wktdata)
    geojson_data = wkt.loads(wktdata)
    #print(geojson_data)
            
    geojson = GeoJSON(data=geojson_data, style = {'color': 'blue', 'fillcolor': 'blue', 'opacity':1, 'weight':1.9, 'fillOpacity':0.1})
    map2.add_layer(geojson)
map2
# Out:
# Map(center=[-37.765549186, 144.92168454], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_…

# %% [markdown]
# Ta-da!
#
# You can see GNAF addresses as blue markers within the meshblock (shown in red).
#
# We hope you enjoyed that little demonstration of how to traverse from a ASGS MeshBlock across to the GNAF Address based on linkset relationships registered in Loc-I.
