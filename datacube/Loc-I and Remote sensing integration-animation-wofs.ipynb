# %% [markdown]
# # Integrating Loc-I and OpenDataCube to animate over time (Wofs)
#
# This notebook shows an example of using Loc-I to fetch location polygons via Loc-I Identifiers (HTTP URIs) and integrating this with Remote sensed data using the OpenDataCube.

# %%
# First we initialise the DataCube module.
import datacube
dc = datacube.Datacube(env='datacube')
dc
# Out:
# Datacube<index=Index<db=PostgresDb<engine=Engine(postgresql://easi_db_user:***@v2-db-easihub-stage-eks.cluster-ro-cvaedcg0qvwd.ap-southeast-2.rds.amazonaws.com:5432/easihub_stage_db)>>>

# %%
dc_products = dc.list_products()
dc_products
# Out:
#                              name  \
# id
# 63         csiro_modis_frac_cover
# 1     fc_percentile_albers_annual
# 2   fc_percentile_albers_seasonal
# 3                   ga_ls5t_ard_3
# 4                   ga_ls7e_ard_3
# ..                            ...
# 57            wofs_annual_summary
# 58           wofs_apr_oct_summary
# 59          wofs_filtered_summary
# 60           wofs_nov_mar_summary
# 61                   wofs_summary
#
#                                           description  eo_sun_elevation  \
# id
# 63  Fractional cover with three bands - MODIS, CSI...               NaN
# 1   Landsat Fractional Cover percentile 25 metre, ...               NaN
# 2   Landsat Fractional Cover percentile 25 metre, ...               NaN
# 3                   Landsat 5 TM ARD, GA Collection 3               NaN
# 4                 Landsat 7 ETM+ ARD, GA Collection 3               NaN
# ..                                                ...               ...
# 57    Water Observations from Space Annual Statistics               NaN
# 58  Water Observations from Space April to October...               NaN
# 59  Water Observations from Space Statistics confi...               NaN
# 60  Water Observations from Space November to Marc...               NaN
# 61           Water Observations from Space Statistics               NaN
#
#     cloud_cover  gqa_stddev_xy  gqa_iterative_mean_x  eo_sun_azimuth  \
# id
# 63          NaN            NaN                   NaN             NaN
# 1           NaN            NaN                   NaN             NaN
# 2           NaN            NaN                   NaN             NaN
# 3           NaN            NaN                   NaN             NaN
# 4           NaN            NaN                   NaN             NaN
# ..          ...            ...                   ...             ...
# 57          NaN            NaN                   NaN             NaN
# 58          NaN            NaN                   NaN             NaN
# 59          NaN            NaN                   NaN             NaN
# 60          NaN            NaN                   NaN             NaN
# 61          NaN            NaN                   NaN             NaN
#
#    creation_time  gqa_iterative_stddev_x label  ...   instrument  \
# id                                              ...
# 63          None                     NaN  None  ...         None
# 1           None                     NaN  None  ...  TM,ETM+,OLI
# 2           None                     NaN  None  ...  TM,ETM+,OLI
# 3           None                     NaN  None  ...         None
# 4           None                     NaN  None  ...         None
# ..           ...                     ...   ...  ...          ...
# 57          None                     NaN  None  ...   TM,ETM,OLI
# 58          None                     NaN  None  ...   TM,ETM,OLI
# 59          None                     NaN  None  ...  TM,ETM+,OLI
# 60          None                     NaN  None  ...   TM,ETM,OLI
# 61          None                     NaN  None  ...  TM,ETM+,OLI
#
#     gqa_stddev_x  gqa_error_message   lat  time  gqa_iterative_stddev_xy  \
# id
# 63           NaN                NaN  None  None                      NaN
# 1            NaN                NaN  None  None                      NaN
# 2            NaN                NaN  None  None                      NaN
# 3            NaN                NaN  None  None                      NaN
# 4            NaN                NaN  None  None                      NaN
# ..           ...                ...   ...   ...                      ...
# 57           NaN                NaN  None  None                      NaN
# 58           NaN                NaN  None  None                      NaN
# 59           NaN                NaN  None  None                      NaN
# 60           NaN                NaN  None  None                      NaN
# 61           NaN                NaN  None  None                      NaN
#
#           crs  resolution             tile_size  spatial_dimensions
# id
# 63        NaN         NaN                   NaN                 NaN
# 1   EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
# 2   EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
# 3         NaN         NaN                   NaN                 NaN
# 4         NaN         NaN                   NaN                 NaN
# ..        ...         ...                   ...                 ...
# 57  EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
# 58  EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
# 59  EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
# 60  EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
# 61  EPSG:3577   (-25, 25)  (100000.0, 100000.0)              (y, x)
#
# [68 rows x 52 columns]

# %% [markdown]
# [
#             [
#               145.0078582763672,
#               -37.980468742815006
#             ],
#             [
#               145.4706573486328,
#               -37.980468742815006
#             ],
#             [
#               145.4706573486328,
#               -37.69251435532741
#             ],
#             [
#               145.0078582763672,
#               -37.69251435532741
#             ],
#             [
#               145.0078582763672,
#               -37.980468742815006
#             ]
#           ]

# %% [markdown]
# Let's initialise a list of known Loc-I Identifiers to enable user selection

# %%
from ipywidgets import interact, interactive
def f(feature_uri):
    display(feature_uri)
    return feature_uri
w = interactive(f, feature_uri=[ 
        ('Barossa (DC)', 'http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/40310'), 
        ("Moonee Valley (C)", 'http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/25060'),
        ('Yarra Ranges (S)', 'http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/27450'),
        ('Mornington Peninsula (S)', 'http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/25340'),
        ('Wagga Wagga (C)', 'http://linked.data.gov.au/dataset/asgs2016/localgovernmentarea/17750')    
    ]);
display(w)
# Out:
# interactive(children=(Dropdown(description='feature_uri', options=(('Barossa (DC)', 'http://linked.data.gov.au…

# %%
sel_feature_uri = w.result

# %%
import requests
import ipyleaflet as ipy 
import ipywidgets as ipyw
from ipyleaflet import GeoJSON, Map, Marker
def get_geom(loci_uri, uri_only_flag=False):
    payload = {
        "uri": loci_uri,
        'uri_only': uri_only_flag,
        'view': 'geometryview'
    }
    url = "https://api.loci.cat/api/v1/location/geometry"
    r = requests.get(url, params=payload)
    res = r.json()
    #get the first geom result as uri
    geojson_data = []
    if len( res['geometry']) > 0:
        geojson_data = res['geometry'][0]
    return geojson_data

# %%
geom_uri = get_geom(sel_feature_uri, uri_only_flag=True)
geom_url = "{}?_format=application/json".format(geom_uri)
geom_url
# Out:
# 'http://gds.loci.cat/geometry/asgs16_lga/25060?_format=application/json'

# %%
geom_data = get_geom(sel_feature_uri)

#load the geometry into geopandas to get the centroid info, bbox, and create a raster mask
import fiona, geopandas
df = geopandas.read_file(geom_url)

def getXY(pt):
    return (pt.x, pt.y)
x,y = getXY(df.centroid)
x_coord = y[0]
y_coord = x[0]

#display the geometry on the leaflet map
geom_data = get_geom(sel_feature_uri, uri_only_flag=False)
curr_geojson_layer = GeoJSON(data=geom_data, 
                    style={
                          'color': 'black', 
                          'opacity': 1, 
                          'weight':1, 
                          'fillColor': 'yellow', 
                          'fillOpacity': 0.3})
map3 = ipy.Map(center=[x_coord, y_coord], zoom=10)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))
map3.add_layer(curr_geojson_layer)
map3
# Out:
# /env/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   if __name__ == '__main__':
# Map(center=[-37.749499924536416, 144.89576166688516], controls=(ZoomControl(options=['position', 'zoom_in_text…

# %% [markdown]
# query = {'lon': (145.0078582763672, 145.4706573486328),
# 'lat': (-37.980468742815006, -37.69251435532741),
# 'time':('2018-01-01', '2018-12-31'),
# 'dask_chunks': { 'latitude': 2048, 'longitude': 2048, 'time': 1},
# 'output_crs': 'epsg:4326',
# 'resolution': (-0.001,0.001),
# 'measurements': ['green_veg', 'dead_veg', 'bare', 'err']
# }

# %%
#select a data product from the DataCube
product = "wofs_annual_summary"
# List metadata for all Landsat NBAR and NBART products available in DEA
dc_products = dc.list_products()
display_columns = ['name', 'description', 'product_type', 'crs', 'resolution', 'spatial_dimensions']
dc_products[dc_products['name'].str.contains(product)][display_columns].set_index('name')
# Out:
#                                                          description  \
# name
# wofs_annual_summary  Water Observations from Space Annual Statistics
#
#                             product_type        crs resolution  \
# name
# wofs_annual_summary  wofs_annual_summary  EPSG:3577  (-25, 25)
#
#                     spatial_dimensions
# name
# wofs_annual_summary             (y, x)

# %%
b = df.bounds
b
# Out:
#          minx       miny        maxx       maxy
# 0  144.846135 -37.789655  144.940362 -37.709197

# %%
#create a query for the chunk in the data product that we want
b = df.bounds

query = {'lon': (b.maxx.values[0], b.minx.values[0]),
'lat': (b.maxy.values[0], b.miny.values[0]),
'time':('1986-01-01', '2018-01-01'),
'dask_chunks': { 'latitude': 2048, 'longitude': 2048, 'time': 1},
'output_crs': 'epsg:4326',
'resolution': (-0.001,0.001),
'measurements': ['count_wet', 'count_clear', 'frequency']
}
# Load data 
ds = dc.load(product=product, group_by='solar_day', **query)
# Get the measurements from the datacube
measurements = dc.list_measurements()
# Restrict to ls8 product of interest
measurements = measurements.loc[product]
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (latitude: 81, longitude: 95, time: 33)
# Coordinates:
#   * time         (time) datetime64[ns] 1986-01-01 1987-01-01 ... 2018-01-01
#   * latitude     (latitude) float64 -37.71 -37.71 -37.71 ... -37.79 -37.79
#   * longitude    (longitude) float64 144.8 144.8 144.8 ... 144.9 144.9 144.9
#     spatial_ref  int32 4326
# Data variables:
#     count_wet    (time, latitude, longitude) int16 dask.array<chunksize=(1, 81, 95), meta=np.ndarray>
#     count_clear  (time, latitude, longitude) int16 dask.array<chunksize=(1, 81, 95), meta=np.ndarray>
#     frequency    (time, latitude, longitude) float32 dask.array<chunksize=(1, 81, 95), meta=np.ndarray>
# Attributes:
#     crs:           epsg:4326
#     grid_mapping:  spatial_ref

# %%
#get mask
import rasterio
import rasterio.features
from datacube.utils import geometry

# get the crs of the geometry and create a data cube geomtry object
crs = geometry.CRS(df.crs)
first_geometry = df.iloc[0]['geometry']
geom = geometry.Geometry(first_geometry, crs=crs)

# using raster io and the scene geobox (from ds) transform the banks geom and generate a mask with
# the same resolution and exten i.e compatible with the ds
mask = rasterio.features.geometry_mask([geom.to_crs(ds.geobox.crs) for geom in geom],
out_shape=ds.geobox.shape,
transform=ds.geobox.affine,
all_touched=True,
invert=True)

# %%
#mask the green_veg raster data
masked_feature = ds.count_wet.where(mask)
masked_feature
# Out:
# <xarray.DataArray 'count_wet' (time: 33, latitude: 81, longitude: 95)>
# dask.array<where, shape=(33, 81, 95), dtype=float64, chunksize=(1, 81, 95), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) datetime64[ns] 1986-01-01 1987-01-01 ... 2018-01-01
#   * latitude     (latitude) float64 -37.71 -37.71 -37.71 ... -37.79 -37.79
#   * longitude    (longitude) float64 144.8 144.8 144.8 ... 144.9 144.9 144.9
#     spatial_ref  int32 4326
# Attributes:
#     units:         1
#     nodata:        -1
#     crs:           epsg:4326
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Plot at a slice in time
# The following viz shows a spatial plot of remote sensed data at a slice in time.

# %%
import matplotlib.pyplot as plt
#plot the selected geom as a mask
cmap_color = plt.cm.cool
vmin_val = 0
vmax_val = 20
fig, ax = plt.subplots()
masked_feature.isel(time=0).plot(cmap=cmap_color, vmin=vmin_val, vmax=vmax_val)
fig.show()

# %%
for i in range(5):
    masked_feature.isel(time=i).plot(cmap=cmap_color, vmin=vmin_val, vmax=vmax_val)
    plt.savefig(f"./images/Python_Animation_01_frame_{i:04}.png")
    plt.show()
    plt.close()

# %%
# !ls ./images/
# Out:
# Python_Animation_01_frame_0000.png
# Python_Animation_01_frame_0001.png
# Python_Animation_01_frame_0002.png
# Python_Animation_01_frame_0003.png
# Python_Animation_01_frame_0004.png
# Python_Animation_ls8_fc_green_veg_01_frame_0000.png
# Python_Animation_ls8_fc_green_veg_01_frame_0001.png
# Python_Animation_ls8_fc_green_veg_01_frame_0002.png
# Python_Animation_ls8_fc_green_veg_01_frame_0003.png
# Python_Animation_ls8_fc_green_veg_01_frame_0004.png

# %%
from matplotlib import pyplot as plt, animation

# Get a handle on the figure and the axes
fig, ax = plt.subplots(figsize=(12,8))

# Plot the initial frame. 
cax =  masked_feature.isel(time=i).plot(cmap=cmap_color, vmin=vmin_val, vmax=vmax_val)

# Next we need to create a function that updates the values for the colormesh, as well as the title.
def animate(frame):
    currdf = masked_feature.isel(time=frame)
    cax.set_array(currdf)    
    ax.set_title("Date = " + str(currdf['time'].values)[:10])


# Finally, we use the animation module to create the animation.
ani = animation.FuncAnimation(
    fig,             # figure
    animate,         # name of the function above
    frames=len(masked_feature.coords["time"])-1,       # Could also be iterable or list
    interval=1000     # ms between frames
)

# %%
from IPython.display import HTML, display
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img682aad833ca94dc5a43e7bdec33d8408">
#   <div class="anim-controls">
#     <input id="_anim_slider682aad833ca94dc5a43e7bdec33d8408" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim682aad833ca94dc5a43e7bdec33d8408.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim682aad833ca94dc5a43e7bdec33d8408.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim682aad833ca94dc5a43e7bdec33d8408.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim682aad833ca94dc5a43e7bdec33d8408.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim682aad833ca94dc5a43e7bdec33d8408.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim682aad833ca94dc5a43e7bdec33d8408.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim682aad833ca94dc5a43e7bdec33d8408.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim682aad833ca94dc5a43e7bdec33d8408.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim682aad833ca94dc5a43e7bdec33d8408.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim682aad833ca94dc5a43e7bdec33d8408.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select682aad833ca94dc5a43e7bdec33d8408"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_682aad833ca94dc5a43e7bdec33d8408"
#              >
#       <label for="_anim_radio1_682aad833ca94dc5a43e7bdec33d8408">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_682aad833ca94dc5a43e7bdec33d8408"
#              checked>
#       <label for="_anim_radio2_682aad833ca94dc5a43e7bdec33d8408">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_682aad833ca94dc5a43e7bdec33d8408"
#              >
#       <label for="_anim_radio3_682aad833ca94dc5a43e7bdec33d8408">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img682aad833ca94dc5a43e7bdec33d8408";
#     var slider_id = "_anim_slider682aad833ca94dc5a43e7bdec33d8408";
#     var loop_select_id = "_anim_loop_select682aad833ca94dc5a43e7bdec33d8408";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAABG20lEQVR4nO3de7xsdV3/8dcb8MZV8KB4QVFDvIWoR9ISBSVDEg4EJeQNkwjN\
# a2WKlJpkYedXapnaEQksQlMEiTBRU0DC8KCAoBimqFwSEOWmqMDn98esLeNm9u3svdeaPev1fDzm\
# cWZ9v2ut+cyes2fPZz7f9f2mqpAkSZIkLb+Nug5AkiRJkvrCBEySJEmSWmICJkmSJEktMQGTJEmS\
# pJaYgEmSJElSS0zAJEmSJKklJmCSJE

# %%
ani.save('../images/Python_Animation_04.mp4')
display(HTML("<video controls><source src='../images/Python_Animation_04.mp4' type='video/mp4'></video>"))
# Out:
# MovieWriter stderr:
# ../images/Python_Animation_04.mp4: No such file or directory
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /env/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# /env/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#
# /env/lib/python3.6/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     363         self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 364                          dpi=self.dpi, **savefig_kwargs)
#     365
#
# /env/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#
# /env/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#
# /env/lib/python3.6/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#
# /env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args)
#     455         with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 456             fh.write(renderer.buffer_rgba())
#     457
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-65-5d1b5fb7ff14> in <module>
# ----> 1 ani.save('../images/Python_Animation_04.mp4')
#       2 display(HTML("<video controls><source src='../images/Python_Animation_04.mp4' type='video/mp4'></video>"))
#
# /env/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# /env/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# /env/lib/python3.6/site-packages/matplotlib/animation.py in finish(self)
#     352     def finish(self):
#     353         """Finish any processing for writing the movie."""
# --> 354         self.cleanup()
#     355
#     356     def grab_frame(self, **savefig_kwargs):
#
# /env/lib/python3.6/site-packages/matplotlib/animation.py in cleanup(self)
#     389         if self._proc.returncode:
#     390             raise subprocess.CalledProcessError(
# --> 391                 self._proc.returncode, self._proc.args, out, err)
#     392
#     393     @classmethod
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '864x576', '-pix_fmt', 'rgba', '-r', '1.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '../images/Python_Animation_04.mp4']' returned non-zero exit status 1.
